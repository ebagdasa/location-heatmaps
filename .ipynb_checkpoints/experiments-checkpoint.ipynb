# %%
# %load_ext autoreload
# %autoreload 2

# %%
from run_experiment import *

# %%
image = get_data('image.jpg')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-988b4360e73c> in <module>
# ----> 1 image = get_data('image.jpg')
#
# ~/Documents/development/location-heatmaps/run_experiment.py in get_data(path, crop_tuple, total_size)
#      56
#      57     with open(path) as f:
# ---> 58         image = Image.open(f).convert('L')
#      59     image = image.crop(crop_tuple)
#      60     true_image = np.asarray(image)
#
# ~/miniconda3/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode)
#    2850         exclusive_fp = True
#    2851
# -> 2852     prefix = fp.read(16)
#    2853
#    2854     preinit()
#
# ~/miniconda3/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
# ...

# %%
from PIL import Image

# %%
with open('image.png', 'rb') as f:
    image = Image.open(f).convert('L')

# %%
image.size
# Out:
# (2048, 1365)

# %%
image
# Out:
# <PIL.Image.Image image mode=L size=2048x1365 at 0x7FEC69E49370>
